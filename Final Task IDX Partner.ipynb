# %% [markdown]
# #**CREDIT RISK ANALYSIS**
# #**END-TO-END SOLUTION**
# ####**VIX PROGRAM_ID/X Partners - Inka Nurul Alfiana**
#
#
# ---
#
#
#
# > **Penjelasan** ***Credit Risk***
#
#
# *Credit risk* adalah risiko yang harus ditanggung oleh seorang individu atau lembaga ketika memberikan pinjaman (biasanya dalam bentuk uang) ke individu atau pihak lain.
#
# Untuk memperkecil risiko kredit ini, biasanya dilakukan proses yang disebut dengan *credit scoring* dan *credit rating* terhadap pihak peminjam.
#
# *Credit score* adalah nilai risiko yang diberikan kepada seorang individu atau organisasi yang mengajukan pinjaman berdasarkan rekam jejak pinjaman dan pembayaran yang dilakukan. Proses pemberian *credit score* ini biasa disebut dengan *credit scoring*.
#
# Terdapat beberapa model *scoring* yang diterapkan lembaga-lembaga, namun kebanyakan lembaga menggunakan model FICO sebagai standart. Model FICO memiliki rentang penilaian 300-850, dimana semakin tinggi nilai score berarti calon debitur dinilai layak untuk diberi pembiayaan atau pinjaman (karena dianggap mampu mengembalikan pinjaman).
#
# Lembaga juga banyak yang menggunakan *risk rating*. Berbanding terbalik dengan *credit scoring*, semakin tinggi nilai *risk rating* menunjukkan bahwa debitur semakin berisiko.

# %% [markdown]
# #**LOADING THE DATA**

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
loan = pd.read_csv("/content/drive/My Drive/loan_data_2007_2014.csv")
loan.info()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 75 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   466285 non-null  int64
#  1   id                           466285 non-null  int64
#  2   member_id                    466285 non-null  int64
#  3   loan_amnt                    466285 non-null  int64
#  4   funded_amnt                  466285 non-null  int64
#  5   funded_amnt_inv              466285 non-null  float64
#  6   term                         466285 non-null  object
#  7   int_rate                     466285 non-null  float64
#  8   installment                  466285 non-null  float64
#  9   grade                        466285 non-null  object
#  10  sub_grade                    466285 non-null  object
#  11  emp_title                    438697 non-null  object
#  12  emp_length                   445277 non-null  object
#  13  home_ownership               466285 non-null  object
#  14  annual_inc                   466281 non-null  float64
#  15  verification_status          466285 non-null  object
#  16  issue_d                      466285 non-null  object
#  17  loan_status                  466285 non-null  object
#  18  pymnt_plan                   466285 non-null  object
#  19  url                          466285 non-null  object
#  20  desc                         125983 non-null  object
#  21  purpose                      466285 non-null  object
#  22  title                        466265 non-null  object
#  23  zip_code                     466285 non-null  object
#  24  addr_state                   466285 non-null  object
#  25  dti                          466285 non-null  float64
#  26  delinq_2yrs                  466256 non-null  float64
#  27  earliest_cr_line             466256 non-null  object
#  28  inq_last_6mths               466256 non-null  float64
#  29  mths_since_last_delinq       215934 non-null  float64
#  30  mths_since_last_record       62638 non-null   float64
#  31  open_acc                     466256 non-null  float64
#  32  pub_rec                      466256 non-null  float64
#  33  revol_bal                    466285 non-null  int64
#  34  revol_util                   465945 non-null  float64
#  35  total_acc                    466256 non-null  float64
#  36  initial_list_status          466285 non-null  object
#  37  out_prncp                    466285 non-null  float64
#  38  out_prncp_inv                466285 non-null  float64
#  39  total_pymnt                  466285 non-null  float64
#  40  total_pymnt_inv              466285 non-null  float64
#  41  total_rec_prncp              466285 non-null  float64
#  42  total_rec_int                466285 non-null  float64
#  43  total_rec_late_fee           466285 non-null  float64
#  44  recoveries                   466285 non-null  float64
#  45  collection_recovery_fee      466285 non-null  float64
#  46  last_pymnt_d                 465909 non-null  object
#  47  last_pymnt_amnt              466285 non-null  float64
#  48  next_pymnt_d                 239071 non-null  object
#  49  last_credit_pull_d           466243 non-null  object
#  50  collections_12_mths_ex_med   466140 non-null  float64
#  51  mths_since_last_major_derog  98974 non-null   float64
#  52  policy_code                  466285 non-null  int64
#  53  application_type             466285 non-null  object
#  54  annual_inc_joint             0 non-null       float64
#  55  dti_joint                    0 non-null       float64
#  56  verification_status_joint    0 non-null       float64
#  57  acc_now_delinq               466256 non-null  float64
#  58  tot_coll_amt                 396009 non-null  float64
#  59  tot_cur_bal                  396009 non-null  float64
#  60  open_acc_6m                  0 non-null       float64
#  61  open_il_6m                   0 non-null       float64
#  62  open_il_12m                  0 non-null       float64
#  63  open_il_24m                  0 non-null       float64
#  64  mths_since_rcnt_il           0 non-null       float64
#  65  total_bal_il                 0 non-null       float64
#  66  il_util                      0 non-null       float64
#  67  open_rv_12m                  0 non-null       float64
#  68  open_rv_24m                  0 non-null       float64
#  69  max_bal_bc                   0 non-null       float64
#  70  all_util                     0 non-null       float64
#  71  total_rev_hi_lim             396009 non-null  float64
#  72  inq_fi                       0 non-null       float64
#  73  total_cu_tl                  0 non-null       float64
#  74  inq_last_12m                 0 non-null       float64
# dtypes: float64(46), int64(7), object(22)
# memory usage: 266.8+ MB

# %%
loan.shape
# Out:
# (466285, 75)

# %% [markdown]
# #**PRE-PROCESSING DATA**

# %%
np.sum(loan.isnull())
# Out:
# Unnamed: 0               0
# id                       0
# member_id                0
# loan_amnt                0
# funded_amnt              0
#                      ...
# all_util            466285
# total_rev_hi_lim     70276
# inq_fi              466285
# total_cu_tl         466285
# inq_last_12m        466285
# Length: 75, dtype: int64

# %%
loan.drop(columns=['all_util','inq_fi','total_cu_tl','inq_last_12m','il_util','open_rv_12m','max_bal_bc','open_rv_24m'
                   ,'open_il_12m','open_il_24m','mths_since_rcnt_il','total_bal_il','open_acc_6m','open_il_6m'
                   ,'verification_status_joint','desc','mths_since_last_delinq','mths_since_last_record'
                   ,'mths_since_last_major_derog','annual_inc_joint','dti_joint','next_pymnt_d','Unnamed: 0']
          ,axis=0,inplace=True)

# %%
loan = loan.drop(columns=['id', 'member_id','funded_amnt', 'funded_amnt_inv'
                          ,'sub_grade','emp_title','issue_d','total_pymnt'
                          , 'total_pymnt_inv', 'total_rec_prncp','out_prncp'
                          , 'out_prncp_inv','zip_code', 'total_rec_prncp'
                          , 'total_rec_int','total_rec_late_fee','last_pymnt_d'
                          , 'last_pymnt_amnt','recoveries'
                          ,'collection_recovery_fee','pymnt_plan','url'
                          ,'initial_list_status','collections_12_mths_ex_med'
                          ,'acc_now_delinq','tot_coll_amt','tot_cur_bal'
                          ,'total_rev_hi_lim']
                 , axis=1)

# %%
loan=loan.dropna(axis=0)

# %%
loan.isna().sum()
# Out:
# loan_amnt              0
# term                   0
# int_rate               0
# installment            0
# grade                  0
# emp_length             0
# home_ownership         0
# annual_inc             0
# verification_status    0
# loan_status            0
# purpose                0
# title                  0
# addr_state             0
# dti                    0
# delinq_2yrs            0
# earliest_cr_line       0
# inq_last_6mths         0
# open_acc               0
# pub_rec                0
# revol_bal              0
# revol_util             0
# total_acc              0
# last_credit_pull_d     0
# policy_code            0
# application_type       0
# dtype: int64

# %%
loan.dtypes
# Out:
# loan_amnt                int64
# term                    object
# int_rate               float64
# installment            float64
# grade                   object
# emp_length              object
# home_ownership          object
# annual_inc             float64
# verification_status     object
# loan_status             object
# purpose                 object
# title                   object
# addr_state              object
# dti                    float64
# delinq_2yrs            float64
# earliest_cr_line        object
# inq_last_6mths         float64
# open_acc               float64
# pub_rec                float64
# revol_bal                int64
# revol_util             float64
# total_acc              float64
# last_credit_pull_d      object
# policy_code              int64
# application_type        object
# dtype: object

# %%
loan
# Out:
#         loan_amnt        term  int_rate  installment grade emp_length  \
# 0            5000   36 months     10.65       162.87     B  10+ years
# 1            2500   60 months     15.27        59.83     C   < 1 year
# 2            2400   36 months     15.96        84.33     C  10+ years
# 3           10000   36 months     13.49       339.31     C  10+ years
# 4            3000   60 months     12.69        67.79     B     1 year
# ...           ...         ...       ...          ...   ...        ...
# 466280      18400   60 months     14.47       432.64     C    4 years
# 466281      22000   60 months     19.97       582.50     D  10+ years
# 466282      20700   60 months     16.99       514.34     D    7 years
# 466283       2000   36 months      7.90        62.59     A    3 years
# 466284      10000   36 months     19.20       367.58     D  10+ years
#
#        home_ownership  annual_inc verification_status  loan_status  ...  \
# 0                RENT     24000.0            Verified   Fully Paid  ...
# 1                RENT     30000.0     Source Verified  Charged Off  ...
# 2                RENT     12252.0        Not Verified   Fully Paid  ...
# 3                RENT     49200.0     Source Verified   Fully Paid  ...
# 4                RENT     80000.0     Source Verified      Current  ...
# ...               ...         ...                 ...          ...  ...
# 466280       MORTGAGE    110000.0     Source Verified      Current  ...
# 466281       MORTGAGE     78000.0            Verified  Charged Off  ...
# 466282       MORTGAGE     46000.0            Verified      Current  ...
# 466283            OWN     83000.0            Verified   Fully Paid  ...
# 466284       MORTGAGE     46000.0            Verified      Current  ...
#
#        earliest_cr_line inq_last_6mths open_acc  pub_rec  revol_bal  \
# 0                Jan-85            1.0      3.0      0.0      13648
# 1                Apr-99            5.0      3.0      0.0       1687
# 2                Nov-01            2.0      2.0      0.0       2956
# 3                Feb-96            1.0     10.0      0.0       5598
# 4                Jan-96            0.0     15.0      0.0      27783
# ...                 ...            ...      ...      ...        ...
# 466280           Apr-03            2.0     18.0      0.0      23208
# 466281           Jun-97            5.0     18.0      1.0      18238
# 466282           Dec-01            2.0     18.0      0.0       6688
# 466283           Feb-03            1.0     21.0      0.0      11404
# 466284           Feb-00            0.0      6.0      0.0      11325
#
#        revol_util  total_acc  last_credit_pull_d  policy_code  \
# 0            83.7        9.0              Jan-16            1
# 1             9.4        4.0              Sep-13            1
# 2            98.5       10.0              Jan-16            1
# 3            21.0       37.0              Jan-15            1
# 4            53.9       38.0              Jan-16            1
# ...           ...        ...                 ...          ...
# 466280       77.6       36.0              Jan-16            1
# 466281       46.3       30.0              Jan-16            1
# 466282       51.1       43.0              Dec-15            1
# 466283       21.5       27.0              Apr-15            1
# 466284       70.8       22.0              Jan-16            1
#
#         application_type
# 0             INDIVIDUAL
# 1             INDIVIDUAL
# 2             INDIVIDUAL
# 3             INDIVIDUAL
# 4             INDIVIDUAL
# ...                  ...
# 466280        INDIVIDUAL
# 466281        INDIVIDUAL
# 466282        INDIVIDUAL
# 466283        INDIVIDUAL
# 466284        INDIVIDUAL
#
# [444893 rows x 25 columns]

# %%
loan['loan_status'].value_counts()
# Out:
# Current                                                212422
# Fully Paid                                             178228
# Charged Off                                             40103
# Late (31-120 days)                                       6494
# In Grace Period                                          3042
# Does not meet the credit policy. Status:Fully Paid       1933
# Late (16-30 days)                                        1148
# Default                                                   784
# Does not meet the credit policy. Status:Charged Off       739
# Name: loan_status, dtype: int64

# %%
#status loan yang tidak masuk target
not_target = ['Current','Late (31-120 days)','In Grace Period','Late (16-30 days)','Default','Does not meet the credit policy. Status:Fully Paid','Does not meet the credit policy. Status:Charged Off']

# %%
#mempersempit kategori target
loan = loan[~loan.loan_status.isin(not_target)]
print(loan.shape)
mapping = {'Fully Paid':0,'Does not meet the credit policy. Status:Fully Paid':0,'Charged Off':1,'Does not meet the credit policy. Status:Charged Off':1}
loan['loan_status']= loan['loan_status'].map(mapping)
print(loan['loan_status'].value_counts())
# Out:
# (218331, 25)
# 0    178228
# 1     40103
# Name: loan_status, dtype: int64
# <ipython-input-32-6edc2e1cbf0b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan['loan_status']= loan['loan_status'].map(mapping)

# %%
#mengidentifikasi kolom fitur yang membantu dalam membuat prediksi lebih baik
for column in loan.columns:
  uniq= loan[column].dropna().unique()
  if len(uniq)>=2:
    print(f'multiple unique values {column} {len(uniq)}')
  else:
    loan=loan.drop(columns=column)
    print(f'only one unique value {column} {uniq}')
# Out:
# multiple unique values loan_amnt 1297
# multiple unique values term 2
# multiple unique values int_rate 483
# multiple unique values installment 41515
# multiple unique values grade 7
# multiple unique values emp_length 11
# multiple unique values home_ownership 6
# multiple unique values annual_inc 16311
# multiple unique values verification_status 3
# multiple unique values loan_status 2
# multiple unique values purpose 14
# multiple unique values title 46319
# multiple unique values addr_state 50
# multiple unique values dti 3856
# multiple unique values delinq_2yrs 22
# multiple unique values earliest_cr_line 615
# multiple unique values inq_last_6mths 9
# multiple unique values open_acc 56
# multiple unique values pub_rec 11
# multiple unique values revol_bal 45127
# multiple unique values revol_util 1180
# multiple unique values total_acc 100
# multiple unique values last_credit_pull_d 102
# only one unique value policy_code [1]
# only one unique value application_type ['INDIVIDUAL']

# %% [markdown]
# > Berdasarkan hasil diatas dapat diketahui bahwa pada variabel 'policy_code' dan 'application_type' hanya memiliki satu nilai unik sehingga pada pengerjaan selanjutnya kedua variabel tersebut akan dihapus.

# %%
loan.dtypes.value_counts()
# Out:
# object     10
# float64    10
# int64       3
# dtype: int64

# %%
#CONTINIOUS FEATURES
float_df = loan.select_dtypes(include=['float','int'])
float_df
# Out:
#         loan_amnt  int_rate  installment  annual_inc  loan_status    dti  \
# 0            5000     10.65       162.87     24000.0            0  27.65
# 1            2500     15.27        59.83     30000.0            1   1.00
# 2            2400     15.96        84.33     12252.0            0   8.72
# 3           10000     13.49       339.31     49200.0            0  20.00
# 5            5000      7.90       156.46     36000.0            0  11.20
# ...           ...       ...          ...         ...          ...    ...
# 466276       8525     18.25       217.65     37536.0            1  12.28
# 466277      18000      7.90       563.23     90000.0            1  10.33
# 466278      10000     18.25       362.78     42000.0            0  11.57
# 466281      22000     19.97       582.50     78000.0            1  18.45
# 466283       2000      7.90        62.59     83000.0            0   5.39
#
#         delinq_2yrs  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  \
# 0               0.0             1.0       3.0      0.0      13648        83.7
# 1               0.0             5.0       3.0      0.0       1687         9.4
# 2               0.0             2.0       2.0      0.0       2956        98.5
# 3               0.0             1.0      10.0      0.0       5598        21.0
# 5               0.0             3.0       9.0      0.0       7963        28.3
# ...             ...             ...       ...      ...        ...         ...
# 466276          4.0             0.0      12.0      0.0       5318        10.7
# 466277          1.0             0.0      16.0      0.0       8224        16.3
# 466278          0.0             0.0       9.0      0.0       3196        28.8
# 466281          0.0             5.0      18.0      1.0      18238        46.3
# 466283          3.0             1.0      21.0      0.0      11404        21.5
#
#         total_acc
# 0             9.0
# 1             4.0
# 2            10.0
# 3            37.0
# 5            12.0
# ...           ...
# 466276       26.0
# 466277       33.0
# 466278       24.0
# 466281       30.0
# 466283       27.0
#
# [218331 rows x 13 columns]

# %%
#CATEGORICAL FEATURES
object_df = loan.select_dtypes(include=['object'])
object_df
# Out:
#               term grade emp_length home_ownership verification_status  \
# 0        36 months     B  10+ years           RENT            Verified
# 1        60 months     C   < 1 year           RENT     Source Verified
# 2        36 months     C  10+ years           RENT        Not Verified
# 3        36 months     C  10+ years           RENT     Source Verified
# 5        36 months     A    3 years           RENT     Source Verified
# ...            ...   ...        ...            ...                 ...
# 466276   60 months     D    5 years       MORTGAGE            Verified
# 466277   36 months     A    3 years           RENT            Verified
# 466278   36 months     D  10+ years           RENT     Source Verified
# 466281   60 months     D  10+ years       MORTGAGE            Verified
# 466283   36 months     A    3 years            OWN            Verified
#
#                    purpose                                  title addr_state  \
# 0              credit_card                               Computer         AZ
# 1                      car                                   bike         GA
# 2           small_business                   real estate business         IL
# 3                    other                               personel         CA
# 5                  wedding  My wedding loan I promise to pay back         AZ
# ...                    ...                                    ...        ...
# 466276             medical                       Medical expenses         MA
# 466277  debt_consolidation                                my loan         MD
# 466278            vacation                               Vacation         VA
# 466281  debt_consolidation                     Debt consolidation         TN
# 466283         credit_card                Credit card refinancing         CA
#
#        earliest_cr_line last_credit_pull_d
# 0                Jan-85             Jan-16
# 1                Apr-99             Sep-13
# 2                Nov-01             Jan-16
# 3                Feb-96             Jan-15
# 5                Nov-04             Sep-15
# ...                 ...                ...
# 466276           Nov-94             Oct-14
# 466277           Jul-98             Oct-14
# 466278           Jun-02             Jan-16
# 466281           Jun-97             Jan-16
# 466283           Feb-03             Apr-15
#
# [218331 rows x 10 columns]

# %%
cols = ['home_ownership', 'verification_status', 'emp_length', 'term', 'addr_state']
for col in cols:
  print(loan[col].value_counts())
# Out:
# MORTGAGE    107888
# RENT         92683
# OWN          17581
# OTHER          136
# NONE            42
# ANY              1
# Name: home_ownership, dtype: int64
# Verified           78581
# Not Verified       78294
# Source Verified    61456
# Name: verification_status, dtype: int64
# 10+ years    67979
# 2 years      21220
# < 1 year     18760
# 3 years      18413
# 5 years      16582
# 1 year       15144
# 4 years      14676
# 6 years      13645
# 7 years      12868
# 8 years      10530
# 9 years       8514
# Name: emp_length, dtype: int64
#  36 months    170890
#  60 months     47441
# Name: term, dtype: int64
# CA    37557
# NY    18677
# TX    16777
# FL    15002
# NJ     8507
# IL     8087
# PA     7310
# VA     6933
# GA     6933
# OH     6628
# NC     5872
# MA     5468
# MD     5211
# AZ     5113
# WA     5077
# MI     4963
# CO     4785
# MN     3813
# MO     3431
# CT     3286
# NV     3198
# OR     2827
# AL     2676
# WI     2633
# LA     2535
# SC     2430
# IN     2273
# TN     1963
# KY     1948
# OK     1816
# KS     1815
# UT     1813
# AR     1498
# HI     1257
# NM     1157
# NH     1010
# WV      950
# RI      940
# DC      754
# MT      635
# AK      583
# DE      548
# WY      519
# SD      469
# VT      366
# MS      265
# NE        7
# IA        6
# ID        6
# ME        4
# Name: addr_state, dtype: int64

# %%
loan = loan.drop(columns=["last_credit_pull_d", "earliest_cr_line", "title",'grade', "addr_state"], axis=1)

# %%
mapping_dict = {"10+ years": "experienced","9 years": "experienced"
                ,"8 years": "experienced","7 years": "experienced"
                ,"6 years": "intermediate","5 years": "intermediate"
                ,"4 years": "intermediate","3 years": "beginner"
                ,"2 years": "beginner","1 year": "beginner"
                ,"< 1 year": "beginner","n/a": "beginner"}

# %%
loan['emp_length']= loan['emp_length'].map(mapping_dict)
loan.head()
# Out:
#    loan_amnt        term  int_rate  installment   emp_length home_ownership  \
# 0       5000   36 months     10.65       162.87  experienced           RENT
# 1       2500   60 months     15.27        59.83     beginner           RENT
# 2       2400   36 months     15.96        84.33  experienced           RENT
# 3      10000   36 months     13.49       339.31  experienced           RENT
# 5       5000   36 months      7.90       156.46     beginner           RENT
#
#    annual_inc verification_status  loan_status         purpose    dti  \
# 0     24000.0            Verified            0     credit_card  27.65
# 1     30000.0     Source Verified            1             car   1.00
# 2     12252.0        Not Verified            0  small_business   8.72
# 3     49200.0     Source Verified            0           other  20.00
# 5     36000.0     Source Verified            0         wedding  11.20
#
#    delinq_2yrs  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  \
# 0          0.0             1.0       3.0      0.0      13648        83.7
# 1          0.0             5.0       3.0      0.0       1687         9.4
# 2          0.0             2.0       2.0      0.0       2956        98.5
# 3          0.0             1.0      10.0      0.0       5598        21.0
# 5          0.0             3.0       9.0      0.0       7963        28.3
#
#    total_acc
# 0        9.0
# 1        4.0
# 2       10.0
# 3       37.0
# 5       12.0

# %%
loan['purpose'].value_counts()
# Out:
# debt_consolidation    127638
# credit_card            43580
# home_improvement       12564
# other                  12161
# major_purchase          5472
# small_business          4367
# car                     3251
# medical                 2424
# wedding                 1927
# moving                  1701
# house                   1394
# vacation                1304
# educational              312
# renewable_energy         236
# Name: purpose, dtype: int64

# %%
#ONE_HOT ENCODING UNTUK VARIABEL DUMMY
cat_cols= ['home_ownership', 'verification_status', 'purpose', 'term', 'emp_length']
dummy_df = pd.get_dummies(loan[cat_cols])
loan = pd.concat([loan, dummy_df], axis=1)
loan = loan.drop(cat_cols, axis=1)
loan
# Out:
#         loan_amnt  int_rate  installment  annual_inc  loan_status    dti  \
# 0            5000     10.65       162.87     24000.0            0  27.65
# 1            2500     15.27        59.83     30000.0            1   1.00
# 2            2400     15.96        84.33     12252.0            0   8.72
# 3           10000     13.49       339.31     49200.0            0  20.00
# 5            5000      7.90       156.46     36000.0            0  11.20
# ...           ...       ...          ...         ...          ...    ...
# 466276       8525     18.25       217.65     37536.0            1  12.28
# 466277      18000      7.90       563.23     90000.0            1  10.33
# 466278      10000     18.25       362.78     42000.0            0  11.57
# 466281      22000     19.97       582.50     78000.0            1  18.45
# 466283       2000      7.90        62.59     83000.0            0   5.39
#
#         delinq_2yrs  inq_last_6mths  open_acc  pub_rec  ...  purpose_other  \
# 0               0.0             1.0       3.0      0.0  ...              0
# 1               0.0             5.0       3.0      0.0  ...              0
# 2               0.0             2.0       2.0      0.0  ...              0
# 3               0.0             1.0      10.0      0.0  ...              1
# 5               0.0             3.0       9.0      0.0  ...              0
# ...             ...             ...       ...      ...  ...            ...
# 466276          4.0             0.0      12.0      0.0  ...              0
# 466277          1.0             0.0      16.0      0.0  ...              0
# 466278          0.0             0.0       9.0      0.0  ...              0
# 466281          0.0             5.0      18.0      1.0  ...              0
# 466283          3.0             1.0      21.0      0.0  ...              0
#
#         purpose_renewable_energy  purpose_small_business  purpose_vacation  \
# 0                              0                       0                 0
# 1                              0                       0                 0
# 2                              0                       1                 0
# 3                              0                       0                 0
# 5                              0                       0                 0
# ...                          ...                     ...               ...
# 466276                         0                       0                 0
# 466277                         0                       0                 0
# 466278                         0                       0                 1
# 466281                         0                       0                 0
# 466283                         0                       0                 0
#
#         purpose_wedding  term_ 36 months  term_ 60 months  \
# 0                     0                1                0
# 1                     0                0                1
# 2                     0                1                0
# 3                     0                1                0
# 5                     1                1                0
# ...                 ...              ...              ...
# 466276                0                0                1
# 466277                0                1                0
# 466278                0                1                0
# 466281                0                0                1
# 466283                0                1                0
#
#         emp_length_beginner  emp_length_experienced  emp_length_intermediate
# 0                         0                       1                        0
# 1                         1                       0                        0
# 2                         0                       1                        0
# 3                         0                       1                        0
# 5                         1                       0                        0
# ...                     ...                     ...                      ...
# 466276                    0                       0                        1
# 466277                    1                       0                        0
# 466278                    0                       1                        0
# 466281                    0                       1                        0
# 466283                    1                       0                        0
#
# [218331 rows x 41 columns]

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 218331 entries, 0 to 466283
# Data columns (total 41 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   loan_amnt                            218331 non-null  int64
#  1   int_rate                             218331 non-null  float64
#  2   installment                          218331 non-null  float64
#  3   annual_inc                           218331 non-null  float64
#  4   loan_status                          218331 non-null  int64
#  5   dti                                  218331 non-null  float64
#  6   delinq_2yrs                          218331 non-null  float64
#  7   inq_last_6mths                       218331 non-null  float64
#  8   open_acc                             218331 non-null  float64
#  9   pub_rec                              218331 non-null  float64
#  10  revol_bal                            218331 non-null  int64
#  11  revol_util                           218331 non-null  float64
#  12  total_acc                            218331 non-null  float64
#  13  home_ownership_ANY                   218331 non-null  uint8
#  14  home_ownership_MORTGAGE              218331 non-null  uint8
#  15  home_ownership_NONE                  218331 non-null  uint8
#  16  home_ownership_OTHER                 218331 non-null  uint8
#  17  home_ownership_OWN                   218331 non-null  uint8
#  18  home_ownership_RENT                  218331 non-null  uint8
#  19  verification_status_Not Verified     218331 non-null  uint8
#  20  verification_status_Source Verified  218331 non-null  uint8
#  21  verification_status_Verified         218331 non-null  uint8
#  22  purpose_car                          218331 non-null  uint8
#  23  purpose_credit_card                  218331 non-null  uint8
#  24  purpose_debt_consolidation           218331 non-null  uint8
#  25  purpose_educational                  218331 non-null  uint8
#  26  purpose_home_improvement             218331 non-null  uint8
#  27  purpose_house                        218331 non-null  uint8
#  28  purpose_major_purchase               218331 non-null  uint8
#  29  purpose_medical                      218331 non-null  uint8
#  30  purpose_moving                       218331 non-null  uint8
#  31  purpose_other                        218331 non-null  uint8
#  32  purpose_renewable_energy             218331 non-null  uint8
#  33  purpose_small_business               218331 non-null  uint8
#  34  purpose_vacation                     218331 non-null  uint8
#  35  purpose_wedding                      218331 non-null  uint8
#  36  term_ 36 months                      218331 non-null  uint8
#  37  term_ 60 months                      218331 non-null  uint8
#  38  emp_length_beginner                  218331 non-null  uint8
#  39  emp_length_experienced               218331 non-null  uint8
#  40  emp_length_intermediate              218331 non-null  uint8
# dtypes: float64(10), int64(3), uint8(28)
# memory usage: 29.2 MB

# %%
features = loan.drop(columns=['loan_status'],axis=1)
target = loan['loan_status']

# %% [markdown]
# #**SETTING UP MODEL EVALUATION CRITERIA**

# %%
def model_performance(target, predictions):
  fig, ((ax1, ax2, ax3)) = plt.subplots(1, 3, sharex=False, sharey=False,figsize=[16,4])
  ax1.bar(x=target.value_counts().index.astype(str), height=target.value_counts().to_list(), data=target, color=['b','r'])

  metric = metrics.confusion_matrix(target,predictions)
  confusion_dataframe = pd.DataFrame(data=metric, index=['Actual_Positive','Actual_Negative'], columns=['Guessed_Positive', 'Guessed_Negative'])
  sns.heatmap(confusion_dataframe, annot=True, fmt="d", cmap="YlGnBu", ax = ax2)

  fpr, tpr, _ = (metrics.roc_curve(target,predictions))
  plt.plot(fpr, tpr)
  

  fpr, tpr, _ = (metrics.roc_curve(target,predictions))
  ax3.plot(fpr, tpr)
  roc_auc = auc(fpr, tpr)
  ax3.plot([0, 1], [0, 1], 'k--', label='AUC = %0.3f'% roc_auc)
  ax3.legend(loc='lower right')
  ax3.plot([0,1],[0,1],'r--')
  ax3.set_xlim([-0.1,1.0])
  ax3.set_ylim([-0.1,1.01])
  ax3.set_ylabel('True Positive Rate')
  ax3.set_xlabel('False Positive Rate')
  plt.tight_layout()
  print(f'Area Under the Curve: {round(roc_auc,2)}')


    
  plt.show()

# %%
import time
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import  cross_val_predict
import pandas as pd 
from sklearn.feature_selection import RFECV
import numpy as np
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
import warnings
import matplotlib.gridspec as gridspec
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.manifold import TSNE
warnings.filterwarnings("ignore")
from scipy import stats
from scipy.stats import shapiro
from scipy.stats import anderson
from sklearn.model_selection import train_test_split
from scipy.stats import mannwhitneyu
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import roc_curve, auc
from sklearn.decomposition import PCA
from imblearn.under_sampling import TomekLinks
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import ClusterCentroids
from imblearn.pipeline import make_pipeline
from sklearn import preprocessing

# %% [markdown]
# #**LOGISTIC REGRESSION WITH VANILLA, BALANCED WEIGHT AND CUSTOM PENALTY**

# %%
lr=LogisticRegression()

# %%
predictions = cross_val_predict(lr, features, target, cv=3)

# %%
model_performance(target, predictions)
# Out:
# Area Under the Curve: 0.5

# %% [markdown]
# > Berdasarkan hasil *heatmap* dapat dihasilkan nilai akurasi sebesar 0.82.

# %%
start_time = time.time()
lr_weight = LogisticRegression(class_weight="balanced")
predictions_weight_balanced = cross_val_predict(lr_weight, features, target, cv=3)
model_performance(target, predictions_weight_balanced)
# Out:
# Area Under the Curve: 0.61
# Duration: 20 seconds

# %% [markdown]
# > Berdasarkan hasil *heatmap* dapat dihasilkan nilai akurasi sebesar 0.56.

# %%
start_time = time.time()
penalty= {1:10,0:1}
lr_weightp = LogisticRegression(class_weight=penalty)
predictionsp = cross_val_predict(lr_weightp, features, target, cv=3)
model_performance(target, predictionsp)
# Out:
# Area Under the Curve: 0.54
# Duration: 11 seconds

# %% [markdown]
# > Berdasarkan hasil *heatmap* dapat dihasilkan nilai akurasi sebesar 0.27.

# %% [markdown]
# #**LOGISTIC REGRESSION WITH SMOTE OVER SAMPLING**

# %%
start_time = time.time()
smote = SMOTE(sampling_strategy='minority')
features_sm, target_sm = smote.fit_resample(features, target)
predictions_sm = cross_val_predict(lr, features_sm, target_sm, cv=3)
model_performance(pd.Series(target_sm), pd.Series(predictions_sm))
# Out:
# Area Under the Curve: 0.61
# Duration: 57 seconds

# %% [markdown]
# > Berdasarkan hasil *heatmap* dapat dihasilkan nilai akurasi sebesar 0.61.

# %% [markdown]
# #**SCALING AND NORMALIZING THE DATA**

# %%
def normalize(subset):
   continious_columns = subset.select_dtypes(include=['float']).columns
   mm_scaler = preprocessing.MinMaxScaler()
   for col in continious_columns:
     subset[col]= mm_scaler.fit_transform(subset[[col]])
   return subset

# %%
lr = LogisticRegression()
scaled_loan = normalize(loan)
features_scaled = scaled_loan.drop(columns=['loan_status'],axis=1)
target_scaled = scaled_loan['loan_status']

# %%
rus = RandomUnderSampler(random_state=0)
rus.fit(features_scaled, target_scaled)
features_sc, target_sc = rus.fit_resample(features_scaled, target_scaled)
predictions_sc = cross_val_predict(lr, features_sc, target_sc, cv=3)
model_performance(pd.Series(target_sc), pd.Series(predictions_sc))
# Out:
# Area Under the Curve: 0.51

# %% [markdown]
# > Berdasarkan hasil *heatmap* dapat dihasilkan nilai akurasi sebesar 0.51.

# %% [markdown]
# #**XGBOOST CLASSIFIER**

# %%
def plot_correlation_heatmap(df):
    corr = df.corr()
    sns.set(style="white")
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    f, ax = plt.subplots(figsize=(11, 9))
    cmap = sns.diverging_palette(220, 10, as_cmap=True)


    sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
    plt.show()
plot_correlation_heatmap(features)

# %%
features.columns
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'home_ownership_ANY',
#        'home_ownership_MORTGAGE', 'home_ownership_NONE',
#        'home_ownership_OTHER', 'home_ownership_OWN', 'home_ownership_RENT',
#        'verification_status_Not Verified',
#        'verification_status_Source Verified', 'verification_status_Verified',
#        'purpose_car', 'purpose_credit_card', 'purpose_debt_consolidation',
#        'purpose_educational', 'purpose_home_improvement', 'purpose_house',
#        'purpose_major_purchase', 'purpose_medical', 'purpose_moving',
#        'purpose_other', 'purpose_renewable_energy', 'purpose_small_business',
#        'purpose_vacation', 'purpose_wedding', 'term_ 36 months',
#        'term_ 60 months', 'emp_length_beginner', 'emp_length_experienced',
#        'emp_length_intermediate'],
#       dtype='object')

# %%
features_corr = features.drop(columns=['home_ownership_RENT','term_ 60 months','home_ownership_NONE', 'purpose_car', 'purpose_credit_card', 'purpose_debt_consolidation',
       'purpose_educational', 'purpose_home_improvement', 'purpose_house',
       'purpose_major_purchase', 'purpose_medical', 'purpose_moving',
       'purpose_other', 'purpose_renewable_energy', 'purpose_small_business',
       'purpose_vacation', 'purpose_wedding'],axis=1)

# %%
print(features_corr.shape)
print(target.shape)
# Out:
# (218331, 23)
# (218331,)

# %%
start_time = time.time()
smote = SMOTE(sampling_strategy='minority')
features_c, target_c = smote.fit_resample(features_corr, target)
print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# Duration: 34 seconds

# %%
import xgboost as xgb
X_train, X_test, Y_train, Y_test = train_test_split(features_c, target_c, test_size=0.33)
model = xgb.XGBClassifier()
param_dist = {"max_depth": [3,5],
              "min_child_weight" : [3,6],
              "n_estimators": [100],
              "learning_rate": [0.05,.16],}
grid_search = GridSearchCV(model, param_grid=param_dist, cv = 3, 
                                   verbose=10, n_jobs=-1, scoring="f1")
grid_search.fit(X_train, Y_train)

grid_search.best_estimator_
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# XGBClassifier(learning_rate=0.16, max_depth=5, min_child_weight=6)

# %% [markdown]
# #**XGBOOST HYPERPARAMETER**

# %%
import time
start_time = time.time()
model = xgb.XGBClassifier(learning_rate=0.01, max_depth=7, n_estimators=100,  gamma=5,colsample_bytree=.6, subsample=0.8, scoring = 'f1',scale_pos_weight=1)
print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# Duration: 0 seconds

# %%
eval_set = [(X_train, Y_train), (X_test, Y_test)]
eval_metric = ["auc","error"]
model.fit(X_train,Y_train, verbose=True, eval_metric=eval_metric, eval_set=eval_set)
# Out:
# [0]	validation_0-auc:0.84895	validation_0-error:0.220031	validation_1-auc:0.845891	validation_1-error:0.219593
# [1]	validation_0-auc:0.882885	validation_0-error:0.196734	validation_1-auc:0.881163	validation_1-error:0.195952
# [2]	validation_0-auc:0.885445	validation_0-error:0.19794	validation_1-auc:0.88477	validation_1-error:0.19732
# [3]	validation_0-auc:0.887258	validation_0-error:0.195469	validation_1-auc:0.887053	validation_1-error:0.194575
# [4]	validation_0-auc:0.888972	validation_0-error:0.193384	validation_1-auc:0.888766	validation_1-error:0.19205
# [5]	validation_0-auc:0.892886	validation_0-error:0.186672	validation_1-auc:0.892715	validation_1-error:0.185759
# [6]	validation_0-auc:0.894295	validation_0-error:0.185215	validation_1-auc:0.894343	validation_1-error:0.183829
# [7]	validation_0-auc:0.894118	validation_0-error:0.1863	validation_1-auc:0.894313	validation_1-error:0.184322
# [8]	validation_0-auc:0.899044	validation_0-error:0.179047	validation_1-auc:0.899358	validation_1-error:0.177666
# [9]	validation_0-auc:0.90484	validation_0-error:0.169363	validation_1-auc:0.905062	validation_1-error:0.167498
# [10]	validation_0-auc:0.903928	validation_0-error:0.170912	validation_1-auc:0.904306	validation_1-error:0.168587
# [11]	validation_0-auc:0.908647	validation_0-error:0.164849	validation_1-auc:0.909141	validation_1-error:0.162551
# [12]	validation_0-auc:0.910253	validation_0-error:0.162554	validation_1-auc:0.910655	validation_1-error:0.16034
# [13]	validation_0-auc:0.911729	validation_0-error:0.158974	validation_1-auc:0.912168	validation_1-error:0.157067
# [14]	validation_0-auc:0.911603	validation_0-error:0.160883	validation_1-auc:0.911995	validation_1-error:0.158683
# [15]	validation_0-auc:0.911238	validation_0-error:0.162554	validation_1-auc:0.911666	validation_1-error:0.160595
# [16]	validation_0-auc:0.910101	validation_0-error:0.164577	validation_1-auc:0.910522	validation_1-error:0.162602
# [17]	validation_0-auc:0.909774	validation_0-error:0.164514	validation_1-auc:0.910105	validation_1-error:0.162763
# [18]	validation_0-auc:0.911008	validation_0-error:0.161888	validation_1-auc:0.911269	validation_1-error:0.159745
# [19]	validation_0-auc:0.912873	validation_0-error:0.158606	validation_1-auc:0.913087	validation_1-error:0.156642
# [20]	validation_0-auc:0.912425	validation_0-error:0.158719	validation_1-auc:0.912627	validation_1-error:0.157033
# [21]	validation_0-auc:0.91289	validation_0-error:0.15838	validation_1-auc:0.913101	validation_1-error:0.157033
# [22]	validation_0-auc:0.912848	validation_0-error:0.158216	validation_1-auc:0.913005	validation_1-error:0.156404
# [23]	validation_0-auc:0.913746	validation_0-error:0.15668	validation_1-auc:0.913933	validation_1-error:0.155053
# [24]	validation_0-auc:0.914351	validation_0-error:0.155407	validation_1-auc:0.914539	validation_1-error:0.153675
# [25]	validation_0-auc:0.914503	validation_0-error:0.154963	validation_1-auc:0.914699	validation_1-error:0.152698
# [26]	validation_0-auc:0.914949	validation_0-error:0.153698	validation_1-auc:0.915096	validation_1-error:0.151924
# [27]	validation_0-auc:0.915863	validation_0-error:0.153242	validation_1-auc:0.915976	validation_1-error:0.151346
# [28]	validation_0-auc:0.916424	validation_0-error:0.151592	validation_1-auc:0.916559	validation_1-error:0.150182
# [29]	validation_0-auc:0.916863	validation_0-error:0.151203	validation_1-auc:0.916969	validation_1-error:0.149382
# [30]	validation_0-auc:0.916636	validation_0-error:0.151534	validation_1-auc:0.916721	validation_1-error:0.149909
# [31]	validation_0-auc:0.917229	validation_0-error:0.150989	validation_1-auc:0.917259	validation_1-error:0.149433
# [32]	validation_0-auc:0.918155	validation_0-error:0.149436	validation_1-auc:0.91816	validation_1-error:0.147759
# [33]	validation_0-auc:0.918176	validation_0-error:0.149042	validation_1-auc:0.91827	validation_1-error:0.14724
# [34]	validation_0-auc:0.918473	validation_0-error:0.14823	validation_1-auc:0.918584	validation_1-error:0.146177
# [35]	validation_0-auc:0.918804	validation_0-error:0.14725	validation_1-auc:0.918853	validation_1-error:0.145438
# [36]	validation_0-auc:0.918762	validation_0-error:0.146877	validation_1-auc:0.918795	validation_1-error:0.14565
# [37]	validation_0-auc:0.919234	validation_0-error:0.146287	validation_1-auc:0.919213	validation_1-error:0.144911
# [38]	validation_0-auc:0.91923	validation_0-error:0.146233	validation_1-auc:0.919226	validation_1-error:0.144741
# [39]	validation_0-auc:0.91932	validation_0-error:0.146471	validation_1-auc:0.919286	validation_1-error:0.145047
# [40]	validation_0-auc:0.92014	validation_0-error:0.144541	validation_1-auc:0.920054	validation_1-error:0.142939
# [41]	validation_0-auc:0.919894	validation_0-error:0.145416	validation_1-auc:0.919809	validation_1-error:0.143908
# [42]	validation_0-auc:0.920265	validation_0-error:0.14488	validation_1-auc:0.920123	validation_1-error:0.143466
# [43]	validation_0-auc:0.919897	validation_0-error:0.145521	validation_1-auc:0.919733	validation_1-error:0.14418
# [44]	validation_0-auc:0.919917	validation_0-error:0.145914	validation_1-auc:0.919752	validation_1-error:0.144265
# [45]	validation_0-auc:0.920023	validation_0-error:0.145638	validation_1-auc:0.919872	validation_1-error:0.143976
# [46]	validation_0-auc:0.920071	validation_0-error:0.145776	validation_1-auc:0.919935	validation_1-error:0.144248
# [47]	validation_0-auc:0.919902	validation_0-error:0.146295	validation_1-auc:0.91978	validation_1-error:0.1448
# [48]	validation_0-auc:0.920026	validation_0-error:0.145881	validation_1-auc:0.919945	validation_1-error:0.144562
# [49]	validation_0-auc:0.920478	validation_0-error:0.144826	validation_1-auc:0.920403	validation_1-error:0.143287
# [50]	validation_0-auc:0.920426	validation_0-error:0.144822	validation_1-auc:0.920341	validation_1-error:0.143457
# [51]	validation_0-auc:0.920856	validation_0-error:0.143946	validation_1-auc:0.920768	validation_1-error:0.142564
# [52]	validation_0-auc:0.920853	validation_0-error:0.144168	validation_1-auc:0.920739	validation_1-error:0.142802
# [53]	validation_0-auc:0.920811	validation_0-error:0.144298	validation_1-auc:0.920727	validation_1-error:0.142905
# [54]	validation_0-auc:0.92081	validation_0-error:0.144055	validation_1-auc:0.920721	validation_1-error:0.142717
# [55]	validation_0-auc:0.920725	validation_0-error:0.144424	validation_1-auc:0.920642	validation_1-error:0.142905
# [56]	validation_0-auc:0.920642	validation_0-error:0.144411	validation_1-auc:0.92054	validation_1-error:0.142956
# [57]	validation_0-auc:0.920499	validation_0-error:0.144838	validation_1-auc:0.920412	validation_1-error:0.14333
# [58]	validation_0-auc:0.920541	validation_0-error:0.144746	validation_1-auc:0.920418	validation_1-error:0.143236
# [59]	validation_0-auc:0.920917	validation_0-error:0.143683	validation_1-auc:0.920781	validation_1-error:0.142428
# [60]	validation_0-auc:0.92075	validation_0-error:0.144114	validation_1-auc:0.920593	validation_1-error:0.142641
# [61]	validation_0-auc:0.920679	validation_0-error:0.144445	validation_1-auc:0.920535	validation_1-error:0.142819
# [62]	validation_0-auc:0.920773	validation_0-error:0.144135	validation_1-auc:0.920634	validation_1-error:0.142905
# [63]	validation_0-auc:0.920781	validation_0-error:0.144122	validation_1-auc:0.920605	validation_1-error:0.142598
# [64]	validation_0-auc:0.920653	validation_0-error:0.144545	validation_1-auc:0.920478	validation_1-error:0.143032
# [65]	validation_0-auc:0.920621	validation_0-error:0.144445	validation_1-auc:0.920483	validation_1-error:0.143049
# [66]	validation_0-auc:0.920537	validation_0-error:0.14442	validation_1-auc:0.920398	validation_1-error:0.143143
# [67]	validation_0-auc:0.920766	validation_0-error:0.143649	validation_1-auc:0.920632	validation_1-error:0.142573
# [68]	validation_0-auc:0.920803	validation_0-error:0.143607	validation_1-auc:0.920648	validation_1-error:0.142573
# [69]	validation_0-auc:0.920686	validation_0-error:0.143662	validation_1-auc:0.920551	validation_1-error:0.142717
# [70]	validation_0-auc:0.920563	validation_0-error:0.143875	validation_1-auc:0.920419	validation_1-error:0.142871
# [71]	validation_0-auc:0.920863	validation_0-error:0.143469	validation_1-auc:0.920691	validation_1-error:0.14236
# [72]	validation_0-auc:0.920762	validation_0-error:0.143771	validation_1-auc:0.920572	validation_1-error:0.142632
# [73]	validation_0-auc:0.920594	validation_0-error:0.144139	validation_1-auc:0.920383	validation_1-error:0.142939
# [74]	validation_0-auc:0.920591	validation_0-error:0.144189	validation_1-auc:0.920376	validation_1-error:0.14316
# [75]	validation_0-auc:0.920625	validation_0-error:0.144231	validation_1-auc:0.920439	validation_1-error:0.143126
# [76]	validation_0-auc:0.920912	validation_0-error:0.143582	validation_1-auc:0.92071	validation_1-error:0.142428
# [77]	validation_0-auc:0.920953	validation_0-error:0.143469	validation_1-auc:0.920762	validation_1-error:0.142479
# [78]	validation_0-auc:0.921223	validation_0-error:0.143	validation_1-auc:0.921032	validation_1-error:0.142003
# [79]	validation_0-auc:0.921222	validation_0-error:0.143092	validation_1-auc:0.921038	validation_1-error:0.142139
# [80]	validation_0-auc:0.921323	validation_0-error:0.143075	validation_1-auc:0.92113	validation_1-error:0.142131
# [81]	validation_0-auc:0.921235	validation_0-error:0.143122	validation_1-auc:0.921048	validation_1-error:0.142258
# [82]	validation_0-auc:0.921381	validation_0-error:0.142707	validation_1-auc:0.921181	validation_1-error:0.141944
# [83]	validation_0-auc:0.92153	validation_0-error:0.142267	validation_1-auc:0.921317	validation_1-error:0.141417
# [84]	validation_0-auc:0.921764	validation_0-error:0.141798	validation_1-auc:0.921548	validation_1-error:0.140949
# [85]	validation_0-auc:0.921722	validation_0-error:0.141849	validation_1-auc:0.921512	validation_1-error:0.141068
# [86]	validation_0-auc:0.921815	validation_0-error:0.141807	validation_1-auc:0.921577	validation_1-error:0.140975
# [87]	validation_0-auc:0.921708	validation_0-error:0.14215	validation_1-auc:0.92145	validation_1-error:0.141179
# [88]	validation_0-auc:0.921843	validation_0-error:0.14179	validation_1-auc:0.921586	validation_1-error:0.140949
# [89]	validation_0-auc:0.921739	validation_0-error:0.142083	validation_1-auc:0.921477	validation_1-error:0.141136
# [90]	validation_0-auc:0.921989	validation_0-error:0.141593	validation_1-auc:0.921719	validation_1-error:0.140499
# [91]	validation_0-auc:0.922151	validation_0-error:0.141283	validation_1-auc:0.921862	validation_1-error:0.140312
# [92]	validation_0-auc:0.92226	validation_0-error:0.140957	validation_1-auc:0.921971	validation_1-error:0.140014
# [93]	validation_0-auc:0.922331	validation_0-error:0.140915	validation_1-auc:0.922035	validation_1-error:0.139921
# [94]	validation_0-auc:0.922375	validation_0-error:0.140827	validation_1-auc:0.922074	validation_1-error:0.13987
# [95]	validation_0-auc:0.922582	validation_0-error:0.140601	validation_1-auc:0.92228	validation_1-error:0.139606
# [96]	validation_0-auc:0.922874	validation_0-error:0.14001	validation_1-auc:0.92254	validation_1-error:0.139155
# [97]	validation_0-auc:0.922994	validation_0-error:0.139763	validation_1-auc:0.922651	validation_1-error:0.138798
# [98]	validation_0-auc:0.922901	validation_0-error:0.139868	validation_1-auc:0.922566	validation_1-error:0.139002
# [99]	validation_0-auc:0.922945	validation_0-error:0.13973	validation_1-auc:0.922615	validation_1-error:0.138951
# XGBClassifier(colsample_bytree=0.6, gamma=5, learning_rate=0.01, max_depth=7,
#               scoring='f1', subsample=0.8)

# %%
error_train = model.evals_result()['validation_0']['error']
error_test =  model.evals_result()['validation_1']['error']
plt.plot(range(len(error_train)), error_train)
plt.plot(range(len(error_test)), error_test)

# %%
predictions = model.predict(X_test)
model_performance(pd.Series(Y_test), pd.Series(predictions))
print(metrics.classification_report(Y_test,predictions))
print(model.get_xgb_params())
print(model.feature_importances_)
print("Precision = {}".format(precision_score(Y_test, predictions, average='macro')))
print("Recall = {}".format(recall_score(Y_test, predictions, average='macro')))
print("Accuracy = {}".format(accuracy_score(Y_test, predictions)))
print(metrics.confusion_matrix(Y_test, predictions))
# Out:
# Area Under the Curve: 0.86
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87     58854
#            1       0.93      0.78      0.85     58777
#
#     accuracy                           0.86    117631
#    macro avg       0.87      0.86      0.86    117631
# weighted avg       0.87      0.86      0.86    117631
#
# {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.6, 'gamma': 5, 'learning_rate': 0.01, 'max_delta_step': 0, 'max_depth': 7, 'min_child_weight': 1, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'binary:logistic', 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.8, 'verbosity': 1, 'scoring': 'f1'}
# [0.00286386 0.01973104 0.00221777 0.0031311  0.00260425 0.00648333
#  0.06412143 0.00362531 0.00875498 0.00066115 0.00228613 0.00134454
#  0.         0.09236241 0.         0.01939618 0.02827432 0.04202707
#  0.04392069 0.5449724  0.03539453 0.03498552 0.04084186]
# Precision = 0.8715141100417235
# Recall = 0.8609936105039675
# Accuracy = 0.8610485331247716
# [[55611  3243]
#  [13102 45675]]

# %%
coefficients = model.feature_importances_
feature_importance = pd.Series(coefficients,
                            index=features_corr.columns, )

feature_importance_ordered = feature_importance.abs().sort_values(ascending=False)
print(feature_importance_ordered )
feature_importance_ordered[0:10].sort_values().plot.barh()
plt.show()
# Out:
# term_ 36 months                        0.544972
# home_ownership_MORTGAGE                0.092362
# inq_last_6mths                         0.064121
# verification_status_Verified           0.043921
# verification_status_Source Verified    0.042027
# emp_length_intermediate                0.040842
# emp_length_beginner                    0.035395
# emp_length_experienced                 0.034986
# verification_status_Not Verified       0.028274
# int_rate                               0.019731
# home_ownership_OWN                     0.019396
# pub_rec                                0.008755
# delinq_2yrs                            0.006483
# open_acc                               0.003625
# annual_inc                             0.003131
# loan_amnt                              0.002864
# dti                                    0.002604
# revol_util                             0.002286
# installment                            0.002218
# total_acc                              0.001345
# revol_bal                              0.000661
# home_ownership_OTHER                   0.000000
# home_ownership_ANY                     0.000000
# dtype: float32

# %% [markdown]
# #**MAX VOTING**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
start_time = time.time()
model1 = DecisionTreeClassifier()
model2 = KNeighborsClassifier()
model3= LogisticRegression(class_weight='balanced')

model1.fit(X_train,Y_train)
model2.fit(X_train,Y_train)
model3.fit(X_train,Y_train)

pred1=model1.predict(X_test)
pred2=model2.predict(X_test)
pred3=model3.predict(X_test)

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# Duration: 631 seconds

# %% [markdown]
# #**DECISION TREE CLASSIFIER**

# %%
model_performance(pd.Series(Y_test), pd.Series(pred1))
# Out:
# Area Under the Curve: 0.81

# %% [markdown]
# > Berdasarkan hasil *heatmap* dapat dihasilkan nilai akurasi sebesar 0.81.

# %% [markdown]
# #**K-NEIGHBOURS CLASSIFIER**

# %%
model_performance(pd.Series(Y_test), pd.Series(pred2))
# Out:
# Area Under the Curve: 0.71

# %% [markdown]
# > Berdasarkan hasil *heatmap* dapat dihasilkan nilai akurasi sebesar 0.71.

# %% [markdown]
# #**LOGISTIC REGRESSION**

# %%
model_performance(pd.Series(Y_test), pd.Series(pred3))
# Out:
# Area Under the Curve: 0.6

# %% [markdown]
# > Berdasarkan hasil *heatmap* dapat dihasilkan nilai akurasi sebesar 0.6.

# %%
import statistics as s

# %% [markdown]
# #**MAX VOTING ENSEMBLING TECHNIQUE**

# %%
final_pred = np.array([])
for i in range(0,len(X_test)):
    final_pred = np.append(final_pred, s.mode([pred1[i], pred2[i], pred3[i]]))

# %%
model_performance(pd.Series(Y_test), pd.Series(final_pred))
print("Recall = {}".format(recall_score(Y_test, final_pred, average='macro')))
# Out:
# Area Under the Curve: 0.77
# Recall = 0.7654191644967252

# %% [markdown]
# > Berdasarkan hasil *heatmap* dapat dihasilkan nilai akurasi sebesar 0.77.

# %%
from sklearn.ensemble import VotingClassifier
model_vc = VotingClassifier(estimators=[('lr', model3), ('dt', model1), ('knn',model2 )], voting='hard')
model_vc.fit(X_train,Y_train)
pred_vc=model_vc.predict(X_test)
model_performance(pd.Series(Y_test), pd.Series(pred_vc))
print("Recall = {}".format(recall_score(Y_test, pred_vc, average='macro')))
# Out:
# Area Under the Curve: 0.76
# Recall = 0.7648750677383731

# %% [markdown]
# > Berdasarkan hasil *heatmap* dapat dihasilkan nilai akurasi sebesar 0.76.
